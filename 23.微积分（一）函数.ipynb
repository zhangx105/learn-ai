# %% [markdown]
# 概要：不懂微积分，看不懂机器学习算法，咋办，啃啃吧。我的目标很明确，就是学会求导数。

# %% [markdown]
# 1.集合。

# %% [markdown]
# 集合是某些个体的总和。

# %% [markdown]
# 邻域的概念：设δ是任意一个正数, 集合{x ©x¦x0 - δ< x < x0 + δ} 称为点
# x0 的一个邻域, 并且记作U( x 0 , δ)。

# %% [markdown]
# 2.实数：自然数，整数，有理数，无理数。

# %% [markdown]
# 实数包括有理数和无理数。

# %% [markdown]
# 有理数包括所有整数和分数（q/p，其中p,q都是整数,p!=0）。

# %% [markdown]
# 有理数的两个特点：有序性和稠密性；可以表示为有限小数，或者无限循环小数。

# %% [markdown]
# 无理数：在数轴上出了有理点外，还有很多空隙，空隙处的点称为无理点；无理点是无限不循环小数。

# %% [markdown]
# 3.函数。

# %% [markdown]
# 偶函数和奇函数，偶函数是当定义域有x属于D(x),同时有-x属于D(x),这时有f(x)=f(-x),
# 如y = x的2次方:

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import math

x = range(-10, 11)
y = np.square(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# 以上是偶函数，图形关于纵坐标对称。

# %% [markdown]
# 奇函数的例子，y=sin(x)：

# %%
x = np.arange(-10, 11, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# sin函数是奇函数，关于原点对称。

# %% [markdown]
# 单调增加函数，sin函数在 -pi/2 - pi/2 上是单调增加函数：

# %%
x = np.arange(-math.pi/2, math.pi/2, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# 单调减少函数，cos函数在 0 - pi 上是单调减少函数：

# %%
x = np.arange(0, math.pi, 0.1)
y = np.cos(x)
plt.plot(x, y)
plt.show()

# %% [markdown]
# 幂函数y=x**n，当n>0时，在（0, + ∞）上单调增加；当n<0时，在（0, + ∞）上单调减少，
# 如下图所示：

# %%
x = np.arange(0, 10, 0.1)
y = x**3
plt.plot(x, y)
plt.show()

# %% [markdown]
# 反函数：函数的自变量和因变量交换后得到的新函数，叫反函数。函数和它的反函数关于直线
# y=x对称。如y=x^2 和y=x^1/2互为反函数:

# %%
x = np.arange(0, 10, 0.1)
y = x**2
plt.plot(x, y)

x = np.arange(0, 80, 1)
y = x**0.5
plt.plot(x, y)

plt.plot([0, 80], [0, 80])
plt.axis([0, 100, 0, 100])

plt.show()

# %% [markdown]
# 复合函数是将一个函数代入另一个函数而得到的新函数。

# %% [markdown]
# 3.映射。

# %% [markdown]
# 设X, Y 是两个非空集合, 如果按照某种确定的
# 法则f , 使得对于每个x ∈ X, 都有唯一的一个y ∈ Y与其对应, 则
# 称这个对应关系f 为定义于X 取值于Y 的一个映射(mapping) , 并
# 且记之为
# f : X → Y.
